# %%
# 1 question
string1 = "hello,"
string2 = "my name is kritika"
result = f"{string1} {string2}"
print(result)
# Out:
# hello, my name is kritika

# %%
# 2 question
# + operator is used for joining samll no of strings onthe other hand join() is used for joining large no of string efficiently.

# %%
# 3 question
txt = "this is python class"
print(txt.find("t",3))
# Out:
# 10

# %%
# 4 question
txt = "this is python class"
print(len(txt))
# Out:
# 20

# %%
# 5 question
txt = "this is python class"
print(txt.upper())
# Out:
# THIS IS PYTHON CLASS

# %%
# 6 question 
txt1 = "THIS IS PYTHON CLASS"
print(txt1.casefold())
# Out:
# this is python class

# %%
# 7 question
txt = "this is python class"
print(txt.replace("python","java"))
# Out:
# this is java class

# %%
# 8 question
txt = "this is python class"
print(txt.split(" "))
# Out:
# ['this', 'is', 'python', 'class']

# %%
# 9 question
txt = "this is python class"
print(txt.startswith("this"))
# Out:
# True

# %%
# 10 question
txt = "this is python class"
print(txt.endswith("class"))
# Out:
# True

# %%
# 11 question
txt2 = "                     hello world                          "
print(txt2.strip())
# Out:
# hello world

# %%
# 12 question
txt = "this is python class"
print(txt.find("this"))
# Out:
# 0

# %%
# 13 question
txt = "this is python class"
print(txt.count("s"))
# Out:
# 4

# %%
# 14 question 
txt = "this is python class"
print(txt.isalpha())
# Out:
# False

# %%
# 15 question
num = "12345"
print(num.isnumeric())
# Out:
# True

# %%
# 16 question
string = "mom"
rev_string = string[::-1]
print(string == rev_string)
# Out:
# True

# %%
# 17 question
txt = "this is python class"
rev_txt = txt[::-1]
print(rev_txt)
# Out:
# ssalc nohtyp si siht

# %%
# 18 question
name = "kritika"
age = "100"
string1 = f"hello {name} your age is {age}"
print(string1)
# Out:
# hello kritika your age is 100

# %%
# 19 question
txt = "this is python class"
txt_slicing = txt[1:-1:4]
print(txt_slicing)
# Out:
# hiyna

# %%
# 20 question
txt = "this is python class"
print(txt.replace("python","java"))
# Out:
# this is java class
